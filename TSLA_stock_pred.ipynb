# %%
import pandas as pd
import numpy as np

# %%
data_AMZN = pd.read_csv('/content/sentiments_tsla_year.csv')

# %%
data_AMZN.head()
# Out:
#    Unnamed: 0        Date        Open        High         Low       Close  \
# 0           0  2021-09-30  260.333344  263.043335  258.333344  258.493347
# 1           1  2021-10-01  259.466675  260.260010  254.529999  258.406677
# 2           2  2021-10-04  265.500000  268.989990  258.706665  260.510010
# 3           3  2021-10-05  261.600006  265.769989  258.066681  260.196655
# 4           4  2021-10-06  258.733337  262.220001  257.739990  260.916656
#
#     Adj Close    Volume Stock Name   Positive   Negative    Neutral  Count
# 0  258.493347  53868000       TSLA  55.555556  14.444444  30.000000     90
# 1  258.406677  51094200       TSLA  50.000000  22.340426  27.659574     94
# 2  260.510010  91449900       TSLA  42.016807  20.168067  37.815126    119
# 3  260.196655  55297800       TSLA  48.863636  22.727273  28.409091     88
# 4  260.916656  43898400       TSLA  52.564103  11.538462  35.897436     78

# %%
data_AMZN = data_AMZN.drop(['Date'],axis=1)

# %%
data_amzn = data_AMZN.iloc[:,2:12]
data_amzn.head()
# Out:
#          High         Low       Close   Adj Close    Volume Stock Name  \
# 0  263.043335  258.333344  258.493347  258.493347  53868000       TSLA
# 1  260.260010  254.529999  258.406677  258.406677  51094200       TSLA
# 2  268.989990  258.706665  260.510010  260.510010  91449900       TSLA
# 3  265.769989  258.066681  260.196655  260.196655  55297800       TSLA
# 4  262.220001  257.739990  260.916656  260.916656  43898400       TSLA
#
#     Positive   Negative    Neutral  Count
# 0  55.555556  14.444444  30.000000     90
# 1  50.000000  22.340426  27.659574     94
# 2  42.016807  20.168067  37.815126    119
# 3  48.863636  22.727273  28.409091     88
# 4  52.564103  11.538462  35.897436     78

# %%
closing_prices = data_amzn['Close']
closing_prices = closing_prices.to_numpy()
closing_prices
# Out:
# array([258.49334717, 258.40667725, 260.51000977, 260.19665527,
#        260.91665649, 264.53668213, 261.82998657, 263.98001099,
#        268.57333374, 270.35998535, 272.77334595, 281.01000977,
#        290.03668213, 288.08999634, 288.6000061 , 298.        ,
#        303.22665405, 341.61999512, 339.47665405, 345.95333862,
#        359.01333618, 371.33334351, 402.86334229, 390.66665649,
#        404.61999512, 409.97000122, 407.36334229, 387.64666748,
#        341.16665649, 355.9833374 , 354.50332642, 344.47332764,
#        337.79666138, 351.57666016, 363.00332642, 365.45999146,
#        379.01998901, 385.62332153, 369.67666626, 372.        ,
#        360.64001465, 378.99667358, 381.58666992, 365.        ,
#        361.5333252 , 338.32333374, 336.33666992, 350.58334351,
#        356.32000732, 334.6000061 , 339.01000977, 322.13665771,
#        319.50332642, 325.32998657, 308.97332764, 310.85665894,
#        299.98001099, 312.84332275, 336.29000854, 355.66665649,
#        364.64666748, 362.82333374, 362.06332397, 356.77999878,
#        352.26000977, 399.92666626, 383.19665527, 362.70666504,
#        354.8999939 , 342.32000732, 352.70666504, 354.79998779,
#        368.73999023, 343.85333252, 349.86999512, 343.50332642,
#        331.8833313 , 332.08999634, 314.6333313 , 310.        ,
#        306.1333313 , 312.47000122, 276.3666687 , 282.1166687 ,
#        312.23999023, 310.41665649, 301.88665771, 297.04666138,
#        307.77334595, 302.44665527, 307.33334351, 310.66665649,
#        301.5166626 , 286.66665649, 291.92001343, 307.47665405,
#        307.79666138, 292.1166687 , 285.66000366, 273.84332275,
#        254.67999268, 266.92333984, 269.95666504, 290.14334106,
#        288.12332153, 293.29666138, 279.76333618, 279.42999268,
#        268.19332886, 274.79998779, 286.32333374, 279.43331909,
#        265.1166687 , 255.45666504, 267.29666138, 280.07666016,
#        290.5333252 , 301.79666138, 307.05334473, 331.32666016,
#        333.03668213, 337.97332764, 336.88000488, 363.94665527,
#        366.52334595, 364.66333008, 359.20001221, 361.52999878,
#        381.81668091, 363.75332642, 348.58666992, 352.42001343,
#        341.82998657, 325.30999756, 328.9833374 , 340.79000854,
#        328.33334351, 334.76333618, 342.7166748 , 325.7333374 ,
#        336.26000977, 335.0166626 , 332.67333984, 292.14001465,
#        293.83666992, 292.50332642, 290.25332642, 300.98001099,
#        303.08334351, 317.54000854, 291.09332275, 288.54998779,
#        262.36999512, 266.67999268, 244.66667175, 242.66667175,
#        256.52999878, 241.45666504, 253.86999512, 236.60333252,
#        236.47332764, 221.30000305, 224.96665955, 209.38667297,
#        219.6000061 , 235.91000366, 253.21000671, 252.75332642,
#        246.78999329, 258.33334351, 234.5166626 , 238.27999878,
#        238.88667297, 241.8666687 , 239.70666504, 232.22999573,
#        215.73666382, 220.88999939, 233.        , 213.1000061 ,
#        216.75999451, 237.03666687, 236.08666992, 235.07000732,
#        245.70666504, 244.91999817, 232.66333008, 228.49000549,
#        224.47332764, 227.26333618, 233.06666565, 231.7333374 ,
#        244.54333496, 250.76333618, 234.34333801, 233.07000732,
#        237.03999329, 238.31333923, 240.06666565, 240.54666138,
#        245.52999878, 247.5       , 271.70666504, 272.24334717,
#        268.43331909, 258.85998535, 274.82000732, 280.8999939 ,
#        297.1499939 , 297.27667236, 300.58666992, 307.39666748,
#        308.6333313 , 288.17001343, 290.42333984, 283.33334351,
#        294.35665894, 286.63000488, 300.02999878, 309.32000732,
#        306.56332397, 303.99667358, 302.86999512, 296.66665649,
#        289.91333008, 296.45333862, 297.09667969, 296.07000732,
#        288.08999634, 284.82000732, 277.70001221, 275.60998535,
#        277.16000366, 270.20999146, 274.42001343, 283.70001221,
#        289.26000977, 299.67999268, 304.42001343, 292.13000488,
#        302.60998535, 303.75      , 303.3500061 , 309.07000732,
#        308.73001099, 300.79998779, 288.58999634, 275.32998657,
#        276.01000977, 282.94000244, 287.80999756, 268.20999146])

# %%
from sklearn.preprocessing import StandardScaler
stock_price_features = ['Low', 'High', 'Close','Positive','Negative','Neutral']
scaler = StandardScaler()
data_amzn[stock_price_features] = scaler.fit_transform(data_amzn[stock_price_features])
data_amzn.head()
# Out:
#        High       Low     Close   Adj Close    Volume Stock Name  Positive  \
# 0 -0.955088 -0.760038 -0.904868  258.493347  53868000       TSLA  1.146504
# 1 -1.014674 -0.845257 -0.906764  258.406677  51094200       TSLA  0.034484
# 2 -0.827781 -0.751673 -0.860760  260.510010  91449900       TSLA -1.563460
# 3 -0.896715 -0.766013 -0.867614  260.196655  55297800       TSLA -0.192974
# 4 -0.972714 -0.773333 -0.851866  260.916656  43898400       TSLA  0.547724
#
#    Negative   Neutral  Count
# 0 -0.991849 -0.291235     90
# 1  0.839750 -0.760667     94
# 2  0.335836  1.276288    119
# 3  0.929485 -0.610333     88
# 4 -1.665939  0.891646     78

# %%
Y = []


Y = data_amzn['Close']
Y = Y.to_numpy()
Y = Y[6:]
Y
# Out:
# array([-0.83189011, -0.78486537, -0.68440149, -0.64532434, -0.59253999,
#        -0.41238996, -0.21496108, -0.25753846, -0.24638366, -0.0407896 ,
#         0.07352633,  0.91325484,  0.86637628,  1.00803253,  1.29367718,
#         1.56313696,  2.25275236,  1.98598982,  2.29117338,  2.40818723,
#         2.35117511,  1.91993746,  0.90333954,  1.22740588,  1.19503549,
#         0.97566214,  0.82963194,  1.13102426,  1.38094514,  1.43467663,
#         1.73125714,  1.8756834 ,  1.52690258,  1.57771789,  1.32925544,
#         1.73074719,  1.78739487,  1.42461583,  1.34879368,  0.84115118,
#         0.79769942,  1.10929871,  1.23476943,  0.75971559,  0.85616996,
#         0.48712069,  0.42952519,  0.55696429,  0.19921598,  0.24040768,
#         0.00251665,  0.28385944,  0.79667885,  1.22047953,  1.41688784,
#         1.37700839,  1.36038566,  1.24483024,  1.14597029,  2.18852219,
#         1.82260803,  1.37445664,  1.20371129,  0.92856531,  1.15573941,
#         1.20152399,  1.50641586,  0.96210178,  1.09369655,  0.95444654,
#         0.70029723,  0.70481735,  0.32301001,  0.22167107,  0.13710037,
#         0.27569425, -0.51394783, -0.38818542,  0.27066352,  0.23078407,
#         0.0442183 , -0.06164076,  0.17297031,  0.05646641,  0.1633467 ,
#         0.236252  ,  0.03612587, -0.28866935, -0.17376938,  0.16648115,
#         0.17348026, -0.16946819, -0.31068658, -0.56913775, -0.9882728 ,
#        -0.7204897 , -0.65414565, -0.21262827, -0.25680958, -0.14365972,
#        -0.43965686, -0.44694766, -0.69271285, -0.54821384, -0.29617841,
#        -0.4468749 , -0.76000471, -0.97128563, -0.71232452, -0.43280392,
#        -0.20409864,  0.04224992,  0.15722264,  0.68812187,  0.725523  ,
#         0.83349594,  0.80958309,  1.40157736,  1.45793403,  1.41725228,
#         1.2977601 ,  1.34872092,  1.79242561,  1.39734893,  1.06562802,
#         1.14946985,  0.91784772,  0.55652709,  0.63686937,  0.8951016 ,
#         0.62265288,  0.7632879 ,  0.93724111,  0.56578627,  0.79602273,
#         0.76882858,  0.71757608, -0.16895758, -0.1318488 , -0.16101132,
#        -0.2102227 ,  0.02438837,  0.07039188,  0.38658405, -0.19185053,
#        -0.24747765, -0.82007919, -0.72581212, -1.20728138, -1.25102482,
#        -0.94780998, -1.27748975, -1.00598884, -1.3836405 , -1.38648393,
#        -1.71835068, -1.63815458, -1.97891573, -1.75553254, -1.39880479,
#        -1.02042392, -1.03041231, -1.16084068, -0.90836772, -1.42927956,
#        -1.34696892, -1.33369991, -1.26852227, -1.31576527, -1.47929291,
#        -1.84003049, -1.72731816, -1.46245159, -1.89769874, -1.81764849,
#        -1.37416273, -1.3949408 , -1.41717696, -1.18453493, -1.20174069,
#        -1.46981514, -1.56109294, -1.6489446 , -1.58792231, -1.46099349,
#        -1.49015568, -1.20997896, -1.07393682, -1.43307047, -1.46092041,
#        -1.37408997, -1.3462397 , -1.30789143, -1.2973931 , -1.18839893,
#        -1.14531161, -0.61587014, -0.60413197, -0.68746385, -0.89684915,
#        -0.54777598, -0.4147962 , -0.0593807 , -0.05661002,  0.01578533,
#         0.1647317 ,  0.19177967, -0.25578834, -0.20650421, -0.36157465,
#        -0.12047575, -0.28947098,  0.00360997,  0.20679846,  0.14650505,
#         0.09036798,  0.06572558, -0.06995212, -0.21765901, -0.07461775,
#        -0.06054677, -0.08300187, -0.25753846, -0.32905875, -0.48478531,
#        -0.5304978 , -0.49659623, -0.64860497, -0.55652453, -0.35355497,
#        -0.23194825, -0.00404527,  0.09962715, -0.16917651,  0.06003872,
#         0.0849728 ,  0.07622425,  0.20133053,  0.19389422,  0.02045095,
#        -0.24660259, -0.53662185, -0.52174857, -0.3701777 , -0.26366251,
#        -0.69234841])

# %%
X = data_amzn.drop(['Stock Name','Count','Volume'],axis = 1)
X.head()
# Out:
#        High       Low     Close   Adj Close  Positive  Negative   Neutral
# 0 -0.955088 -0.760038 -0.904868  258.493347  1.146504 -0.991849 -0.291235
# 1 -1.014674 -0.845257 -0.906764  258.406677  0.034484  0.839750 -0.760667
# 2 -0.827781 -0.751673 -0.860760  260.510010 -1.563460  0.335836  1.276288
# 3 -0.896715 -0.766013 -0.867614  260.196655 -0.192974  0.929485 -0.610333
# 4 -0.972714 -0.773333 -0.851866  260.916656  0.547724 -1.665939  0.891646

# %%
import numpy as np

# Assuming df is your DataFrame with 8 columns and multiple rows
# Convert the DataFrame to a numpy array
data = X.to_numpy()

# Define the shape of the 3D array
num_rows = data.shape[0] - 6  # Number of 2D arrays
num_arrays_per_2d = 7  # Number of 1D arrays per 2D array
num_cols = data.shape[1]  # Number of columns in the DataFrame
shape_3d = (num_rows, num_arrays_per_2d, num_cols)

# Initialize the 3D array
array_3d = np.zeros(shape_3d)

# Construct the 3D array
for i in range(num_rows):
    # Extract the rows for the current 2D array
    rows = data[i:i+num_arrays_per_2d, :]
    # Assign the rows to the corresponding 2D array
    array_3d[i, :, :] = rows

array_3d
# Out:
# array([[[-0.95508788, -0.76003767, -0.90486816, ...,  1.14650403,
#          -0.99184941, -0.29123518],
#         [-1.01467375, -0.84525714, -0.90676378, ...,  0.0344844 ,
#           0.83974977, -0.7606674 ],
#         [-0.82778094, -0.75167285, -0.86076028, ..., -1.56345977,
#           0.3358365 ,  1.27628829],
#         ...,
#         [-0.97271394, -0.77333261, -0.85186621, ...,  0.54772423,
#          -1.66593865,  0.89164647],
#         [-0.84183853, -0.69744893, -0.77269002, ..., -0.47688229,
#          -0.78678619,  1.15817963],
#         [-0.90335171, -0.71589692, -0.83189011, ...,  2.25852366,
#          -0.99184941, -1.40554398]],
#
#        [[-1.01467375, -0.84525714, -0.90676378, ...,  0.0344844 ,
#           0.83974977, -0.7606674 ],
#         [-0.82778094, -0.75167285, -0.86076028, ..., -1.56345977,
#           0.3358365 ,  1.27628829],
#         [-0.89671523, -0.76601263, -0.86761388, ..., -0.19297416,
#           0.92948517, -0.6103327 ],
#         ...,
#         [-0.84183853, -0.69744893, -0.77269002, ..., -0.47688229,
#          -0.78678619,  1.15817963],
#         [-0.90335171, -0.71589692, -0.83189011, ...,  2.25852366,
#          -0.99184941, -1.40554398],
#         [-0.8686706 , -0.68161508, -0.78486537, ..., -0.7029602 ,
#           0.7852001 ,  0.02546311]],
#
#        [[-0.82778094, -0.75167285, -0.86076028, ..., -1.56345977,
#           0.3358365 ,  1.27628829],
#         [-0.89671523, -0.76601263, -0.86761388, ..., -0.19297416,
#           0.92948517, -0.6103327 ],
#         [-0.97271394, -0.77333261, -0.85186621, ...,  0.54772423,
#          -1.66593865,  0.89164647],
#         ...,
#         [-0.90335171, -0.71589692, -0.83189011, ...,  2.25852366,
#          -0.99184941, -1.40554398],
#         [-0.8686706 , -0.68161508, -0.78486537, ..., -0.7029602 ,
#           0.7852001 ,  0.02546311],
#         [-0.78960257, -0.5989352 , -0.68440149, ..., -0.05254322,
#          -1.51853551,  1.36569356]],
#
#        ...,
#
#        [[ 0.04674248,  0.1242699 ,  0.20133053, ..., -1.23091725,
#          -0.07642801,  1.2995367 ],
#         [ 0.12145675,  0.29859209,  0.19389422, ..., -0.58330428,
#           1.38508619, -0.61314661],
#         [ 0.13151861,  0.18768055,  0.02045095, ...,  1.51717724,
#          -0.4763694 , -1.10839497],
#         ...,
#         [-0.49574018, -0.43544289, -0.53662185, ..., -0.43101219,
#           1.05208877, -0.47781712],
#         [-0.50451761, -0.49168331, -0.52174857, ...,  1.70251384,
#          -1.12071941, -0.7369587 ],
#         [-0.40646787, -0.33035657, -0.3701777 , ..., -0.55423188,
#          -0.52185293,  1.00660684]],
#
#        [[ 0.12145675,  0.29859209,  0.19389422, ..., -0.58330428,
#           1.38508619, -0.61314661],
#         [ 0.13151861,  0.18768055,  0.02045095, ...,  1.51717724,
#          -0.4763694 , -1.10839497],
#         [-0.13629701, -0.14415899, -0.24660259, ...,  1.11970837,
#           0.96759569, -1.95867076],
#         ...,
#         [-0.50451761, -0.49168331, -0.52174857, ...,  1.70251384,
#          -1.12071941, -0.7369587 ],
#         [-0.40646787, -0.33035657, -0.3701777 , ..., -0.55423188,
#          -0.52185293,  1.00660684],
#         [-0.39940347, -0.32901224, -0.26366251, ...,  0.70169618,
#          -0.01243739, -0.69238635]],
#
#        [[ 0.13151861,  0.18768055,  0.02045095, ...,  1.51717724,
#          -0.4763694 , -1.10839497],
#         [-0.13629701, -0.14415899, -0.24660259, ...,  1.11970837,
#           0.96759569, -1.95867076],
#         [-0.49574018, -0.43544289, -0.53662185, ..., -0.43101219,
#           1.05208877, -0.47781712],
#         ...,
#         [-0.40646787, -0.33035657, -0.3701777 , ..., -0.55423188,
#          -0.52185293,  1.00660684],
#         [-0.39940347, -0.32901224, -0.26366251, ...,  0.70169618,
#          -0.01243739, -0.69238635],
#         [-0.51393725, -0.59318452, -0.69234841, ...,  0.0344844 ,
#           0.62823062, -0.57777173]]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = array_3d


print(len(X))
print(len(Y))
# Out:
# 246
# 246

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

split_index = int(len(X) * 0.8)  # 95-5 split
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = Y[:split_index], Y[split_index:]

print(X_train.shape)

# Reshape X_train and X_test to include the time dimension


# Step 2: Define the LSTM Model
model = Sequential([layers.Input((X_train.shape[1], X_train.shape[2])),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

# Step 3: Compile the Model


# Step 4: Train the Model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100)

# Step 5: Evaluate the Model (if needed)
# loss = model.evaluate(X_test, y_test)

# Step 6: Make Predictions
predictions = model.predict(X_test)

# Print the predicted closing prices for the next 7 days
print("Predicted closing prices for the next 7 days:")
print(predictions[-1])
# Out:
# (196, 7, 7)
# Epoch 1/100
# 7/7 [==============================] - 6s 200ms/step - loss: 1.2271 - mean_absolute_error: 0.9510 - val_loss: 0.1525 - val_mean_absolute_error: 0.3050
# Epoch 2/100
# 7/7 [==============================] - 0s 20ms/step - loss: 1.2098 - mean_absolute_error: 0.9435 - val_loss: 0.1841 - val_mean_absolute_error: 0.3407
# Epoch 3/100
# 7/7 [==============================] - 0s 20ms/step - loss: 1.1613 - mean_absolute_error: 0.9244 - val_loss: 0.0965 - val_mean_absolute_error: 0.2465
# Epoch 4/100
# 7/7 [==============================] - 0s 36ms/step - loss: 1.0889 - mean_absolute_error: 0.8920 - val_loss: 0.1014 - val_mean_absolute_error: 0.2499
# Epoch 5/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.9911 - mean_absolute_error: 0.8524 - val_loss: 0.0677 - val_mean_absolute_error: 0.2123
# Epoch 6/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.8580 - mean_absolute_error: 0.7823 - val_loss: 0.0822 - val_mean_absolute_error: 0.2235
# Epoch 7/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.6971 - mean_absolute_error: 0.6958 - val_loss: 0.0320 - val_mean_absolute_error: 0.1519
# Epoch 8/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4891 - mean_absolute_error: 0.5604 - val_loss: 0.0225 - val_mean_absolute_error: 0.1284
# Epoch 9/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.3206 - mean_absolute_error: 0.4157 - val_loss: 0.0500 - val_mean_absolute_error: 0.1901
# Epoch 10/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2064 - mean_absolute_error: 0.3211 - val_loss: 0.0772 - val_mean_absolute_error: 0.2551
# Epoch 11/100
# 7/7 [==============================] - 0s 44ms/step - loss: 0.1470 - mean_absolute_error: 0.2859 - val_loss: 0.0822 - val_mean_absolute_error: 0.2633
# Epoch 12/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.1067 - mean_absolute_error: 0.2432 - val_loss: 0.0200 - val_mean_absolute_error: 0.1061
# Epoch 13/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0765 - mean_absolute_error: 0.2004 - val_loss: 0.0206 - val_mean_absolute_error: 0.1110
# Epoch 14/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0689 - mean_absolute_error: 0.1927 - val_loss: 0.0153 - val_mean_absolute_error: 0.0950
# Epoch 15/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0502 - mean_absolute_error: 0.1691 - val_loss: 0.0247 - val_mean_absolute_error: 0.1286
# Epoch 16/100
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0435 - mean_absolute_error: 0.1597 - val_loss: 0.0215 - val_mean_absolute_error: 0.1171
# Epoch 17/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0387 - mean_absolute_error: 0.1527 - val_loss: 0.0232 - val_mean_absolute_error: 0.1265
# Epoch 18/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0344 - mean_absolute_error: 0.1435 - val_loss: 0.0105 - val_mean_absolute_error: 0.0767
# Epoch 19/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0327 - mean_absolute_error: 0.1367 - val_loss: 0.0124 - val_mean_absolute_error: 0.0873
# Epoch 20/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0309 - mean_absolute_error: 0.1357 - val_loss: 0.0091 - val_mean_absolute_error: 0.0731
# Epoch 21/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0284 - mean_absolute_error: 0.1276 - val_loss: 0.0125 - val_mean_absolute_error: 0.0882
# Epoch 22/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0367 - mean_absolute_error: 0.1475 - val_loss: 0.0753 - val_mean_absolute_error: 0.2622
# Epoch 23/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0689 - mean_absolute_error: 0.2184 - val_loss: 0.0342 - val_mean_absolute_error: 0.1683
# Epoch 24/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0331 - mean_absolute_error: 0.1464 - val_loss: 0.0160 - val_mean_absolute_error: 0.1050
# Epoch 25/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0297 - mean_absolute_error: 0.1325 - val_loss: 0.0107 - val_mean_absolute_error: 0.0832
# Epoch 26/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0208 - mean_absolute_error: 0.1067 - val_loss: 0.0092 - val_mean_absolute_error: 0.0761
# Epoch 27/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0189 - mean_absolute_error: 0.1044 - val_loss: 0.0162 - val_mean_absolute_error: 0.1078
# Epoch 28/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0200 - mean_absolute_error: 0.1093 - val_loss: 0.0150 - val_mean_absolute_error: 0.1041
# Epoch 29/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0181 - mean_absolute_error: 0.1010 - val_loss: 0.0076 - val_mean_absolute_error: 0.0699
# Epoch 30/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0160 - mean_absolute_error: 0.0969 - val_loss: 0.0052 - val_mean_absolute_error: 0.0575
# Epoch 31/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0158 - mean_absolute_error: 0.0958 - val_loss: 0.0044 - val_mean_absolute_error: 0.0537
# Epoch 32/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0146 - mean_absolute_error: 0.0910 - val_loss: 0.0058 - val_mean_absolute_error: 0.0600
# Epoch 33/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0159 - mean_absolute_error: 0.0949 - val_loss: 0.0071 - val_mean_absolute_error: 0.0665
# Epoch 34/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0136 - mean_absolute_error: 0.0887 - val_loss: 0.0077 - val_mean_absolute_error: 0.0716
# Epoch 35/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0132 - mean_absolute_error: 0.0859 - val_loss: 0.0120 - val_mean_absolute_error: 0.0947
# Epoch 36/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0138 - mean_absolute_error: 0.0911 - val_loss: 0.0036 - val_mean_absolute_error: 0.0489
# Epoch 37/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0173 - mean_absolute_error: 0.1039 - val_loss: 0.0055 - val_mean_absolute_error: 0.0592
# Epoch 38/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0135 - mean_absolute_error: 0.0904 - val_loss: 0.0073 - val_mean_absolute_error: 0.0695
# Epoch 39/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0159 - mean_absolute_error: 0.0956 - val_loss: 0.0030 - val_mean_absolute_error: 0.0450
# Epoch 40/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0123 - mean_absolute_error: 0.0872 - val_loss: 0.0030 - val_mean_absolute_error: 0.0437
# Epoch 41/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0105 - mean_absolute_error: 0.0765 - val_loss: 0.0030 - val_mean_absolute_error: 0.0436
# Epoch 42/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0107 - mean_absolute_error: 0.0772 - val_loss: 0.0036 - val_mean_absolute_error: 0.0484
# Epoch 43/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0146 - mean_absolute_error: 0.0946 - val_loss: 0.0078 - val_mean_absolute_error: 0.0737
# Epoch 44/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0110 - mean_absolute_error: 0.0820 - val_loss: 0.0089 - val_mean_absolute_error: 0.0798
# Epoch 45/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0155 - mean_absolute_error: 0.0970 - val_loss: 0.0044 - val_mean_absolute_error: 0.0530
# Epoch 46/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0137 - mean_absolute_error: 0.0910 - val_loss: 0.0182 - val_mean_absolute_error: 0.1275
# Epoch 47/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0159 - mean_absolute_error: 0.0980 - val_loss: 0.0036 - val_mean_absolute_error: 0.0461
# Epoch 48/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0206 - mean_absolute_error: 0.1158 - val_loss: 0.0080 - val_mean_absolute_error: 0.0764
# Epoch 49/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0129 - mean_absolute_error: 0.0872 - val_loss: 0.0024 - val_mean_absolute_error: 0.0409
# Epoch 50/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0101 - mean_absolute_error: 0.0783 - val_loss: 0.0071 - val_mean_absolute_error: 0.0734
# Epoch 51/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0105 - mean_absolute_error: 0.0795 - val_loss: 0.0089 - val_mean_absolute_error: 0.0824
# Epoch 52/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0107 - mean_absolute_error: 0.0798 - val_loss: 0.0046 - val_mean_absolute_error: 0.0555
# Epoch 53/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0111 - mean_absolute_error: 0.0781 - val_loss: 0.0051 - val_mean_absolute_error: 0.0599
# Epoch 54/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0092 - mean_absolute_error: 0.0755 - val_loss: 0.0049 - val_mean_absolute_error: 0.0549
# Epoch 55/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0084 - mean_absolute_error: 0.0717 - val_loss: 0.0086 - val_mean_absolute_error: 0.0832
# Epoch 56/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0116 - mean_absolute_error: 0.0867 - val_loss: 0.0113 - val_mean_absolute_error: 0.0988
# Epoch 57/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0146 - mean_absolute_error: 0.0976 - val_loss: 0.0051 - val_mean_absolute_error: 0.0593
# Epoch 58/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0127 - mean_absolute_error: 0.0909 - val_loss: 0.0156 - val_mean_absolute_error: 0.1170
# Epoch 59/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0125 - mean_absolute_error: 0.0931 - val_loss: 0.0025 - val_mean_absolute_error: 0.0394
# Epoch 60/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0090 - mean_absolute_error: 0.0754 - val_loss: 0.0019 - val_mean_absolute_error: 0.0357
# Epoch 61/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0066 - mean_absolute_error: 0.0611 - val_loss: 0.0025 - val_mean_absolute_error: 0.0420
# Epoch 62/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0066 - mean_absolute_error: 0.0626 - val_loss: 0.0033 - val_mean_absolute_error: 0.0456
# Epoch 63/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0071 - mean_absolute_error: 0.0649 - val_loss: 0.0089 - val_mean_absolute_error: 0.0874
# Epoch 64/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0108 - mean_absolute_error: 0.0821 - val_loss: 0.0045 - val_mean_absolute_error: 0.0583
# Epoch 65/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0094 - mean_absolute_error: 0.0774 - val_loss: 0.0080 - val_mean_absolute_error: 0.0802
# Epoch 66/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0125 - mean_absolute_error: 0.0917 - val_loss: 0.0122 - val_mean_absolute_error: 0.1033
# Epoch 67/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0127 - mean_absolute_error: 0.0925 - val_loss: 0.0029 - val_mean_absolute_error: 0.0441
# Epoch 68/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0106 - mean_absolute_error: 0.0831 - val_loss: 0.0090 - val_mean_absolute_error: 0.0872
# Epoch 69/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0080 - mean_absolute_error: 0.0707 - val_loss: 0.0034 - val_mean_absolute_error: 0.0465
# Epoch 70/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0073 - mean_absolute_error: 0.0670 - val_loss: 0.0017 - val_mean_absolute_error: 0.0339
# Epoch 71/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0052 - mean_absolute_error: 0.0546 - val_loss: 0.0029 - val_mean_absolute_error: 0.0444
# Epoch 72/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0060 - mean_absolute_error: 0.0580 - val_loss: 0.0085 - val_mean_absolute_error: 0.0864
# Epoch 73/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0064 - mean_absolute_error: 0.0599 - val_loss: 0.0021 - val_mean_absolute_error: 0.0379
# Epoch 74/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0045 - mean_absolute_error: 0.0504 - val_loss: 0.0020 - val_mean_absolute_error: 0.0372
# Epoch 75/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0043 - mean_absolute_error: 0.0491 - val_loss: 0.0013 - val_mean_absolute_error: 0.0305
# Epoch 76/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0047 - mean_absolute_error: 0.0519 - val_loss: 0.0031 - val_mean_absolute_error: 0.0455
# Epoch 77/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0051 - mean_absolute_error: 0.0557 - val_loss: 0.0123 - val_mean_absolute_error: 0.1063
# Epoch 78/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0101 - mean_absolute_error: 0.0835 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 79/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0063 - mean_absolute_error: 0.0614 - val_loss: 0.0022 - val_mean_absolute_error: 0.0390
# Epoch 80/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0044 - mean_absolute_error: 0.0505 - val_loss: 0.0014 - val_mean_absolute_error: 0.0309
# Epoch 81/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0036 - mean_absolute_error: 0.0455 - val_loss: 0.0020 - val_mean_absolute_error: 0.0376
# Epoch 82/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0034 - mean_absolute_error: 0.0444 - val_loss: 0.0015 - val_mean_absolute_error: 0.0310
# Epoch 83/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0035 - mean_absolute_error: 0.0448 - val_loss: 0.0035 - val_mean_absolute_error: 0.0533
# Epoch 84/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0036 - mean_absolute_error: 0.0460 - val_loss: 8.2552e-04 - val_mean_absolute_error: 0.0240
# Epoch 85/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0032 - mean_absolute_error: 0.0423 - val_loss: 8.1420e-04 - val_mean_absolute_error: 0.0238
# Epoch 86/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0038 - mean_absolute_error: 0.0478 - val_loss: 0.0101 - val_mean_absolute_error: 0.0965
# Epoch 87/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0059 - mean_absolute_error: 0.0628 - val_loss: 0.0019 - val_mean_absolute_error: 0.0360
# Epoch 88/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0063 - mean_absolute_error: 0.0652 - val_loss: 0.0038 - val_mean_absolute_error: 0.0558
# Epoch 89/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0050 - mean_absolute_error: 0.0547 - val_loss: 0.0026 - val_mean_absolute_error: 0.0456
# Epoch 90/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0035 - mean_absolute_error: 0.0454 - val_loss: 6.7709e-04 - val_mean_absolute_error: 0.0210
# Epoch 91/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0031 - mean_absolute_error: 0.0416 - val_loss: 0.0060 - val_mean_absolute_error: 0.0736
# Epoch 92/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0050 - mean_absolute_error: 0.0586 - val_loss: 6.2926e-04 - val_mean_absolute_error: 0.0201
# Epoch 93/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0043 - mean_absolute_error: 0.0521 - val_loss: 0.0039 - val_mean_absolute_error: 0.0570
# Epoch 94/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0054 - mean_absolute_error: 0.0588 - val_loss: 0.0014 - val_mean_absolute_error: 0.0306
# Epoch 95/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0027 - mean_absolute_error: 0.0413 - val_loss: 6.6373e-04 - val_mean_absolute_error: 0.0202
# Epoch 96/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 6.8148e-04 - val_mean_absolute_error: 0.0201
# Epoch 97/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0025 - mean_absolute_error: 0.0393 - val_loss: 9.2560e-04 - val_mean_absolute_error: 0.0246
# Epoch 98/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0032 - mean_absolute_error: 0.0432 - val_loss: 0.0029 - val_mean_absolute_error: 0.0493
# Epoch 99/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0042 - mean_absolute_error: 0.0535 - val_loss: 0.0011 - val_mean_absolute_error: 0.0271
# Epoch 100/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0022 - mean_absolute_error: 0.0366 - val_loss: 4.7406e-04 - val_mean_absolute_error: 0.0176
# 2/2 [==============================] - 1s 10ms/step
# Predicted closing prices for the next 7 days:
# [-0.6828553]

# %%
predictions
# Out:
# array([[128.31357 ],
#        [128.88106 ],
#        [127.09688 ],
#        [124.498695],
#        [124.40434 ],
#        [121.48812 ],
#        [118.03388 ],
#        [116.40267 ],
#        [114.50851 ],
#        [115.73917 ],
#        [115.71728 ],
#        [117.26955 ],
#        [115.77217 ]], dtype=float32)

# %%
len(y_test)
yy = y_test[6:]
yy
# Out:
# array([118.54000092, 117.30999756, 113.77999878, 115.15000153,
#        114.41000366, 118.01000214, 114.80000305])

# %%
import matplotlib.pyplot as plt


plt.plot(predictions, label='Training Loss')
plt.plot(y_test, label='Validation Loss')
plt.ylabel('prices')
plt.legend()
plt.show()

# %%
X_normal = data_amzn.drop(['Stock Name','Count','Volume','Positive','Negative','Neutral'],axis = 1)
X_normal.head()
# Out:
#        High       Low     Close   Adj Close
# 0 -0.955088 -0.760038 -0.904868  258.493347
# 1 -1.014674 -0.845257 -0.906764  258.406677
# 2 -0.827781 -0.751673 -0.860760  260.510010
# 3 -0.896715 -0.766013 -0.867614  260.196655
# 4 -0.972714 -0.773333 -0.851866  260.916656

# %%
import numpy as np

# Assuming df is your DataFrame with 8 columns and multiple rows
# Convert the DataFrame to a numpy array
data_normal = X_normal.to_numpy()

# Define the shape of the 3D array
num_rows = data_normal.shape[0] - 6  # Number of 2D arrays
num_arrays_per_2d = 7  # Number of 1D arrays per 2D array
num_cols = data_normal.shape[1]  # Number of columns in the DataFrame
shape_3d = (num_rows, num_arrays_per_2d, num_cols)

# Initialize the 3D array
array_3d_normal = np.zeros(shape_3d)

# Construct the 3D array
for i in range(num_rows):
    # Extract the rows for the current 2D array
    rows = data_normal[i:i+num_arrays_per_2d, :]
    # Assign the rows to the corresponding 2D array
    array_3d_normal[i, :, :] = rows

array_3d_normal
# Out:
# array([[[-9.55087878e-01, -7.60037666e-01, -9.04868163e-01,
#           2.58493347e+02],
#         [-1.01467375e+00, -8.45257136e-01, -9.06763784e-01,
#           2.58406677e+02],
#         [-8.27780937e-01, -7.51672854e-01, -8.60760278e-01,
#           2.60510010e+02],
#         ...,
#         [-9.72713938e-01, -7.73332609e-01, -8.51866214e-01,
#           2.60916656e+02],
#         [-8.41838535e-01, -6.97448933e-01, -7.72690016e-01,
#           2.64536682e+02],
#         [-9.03351712e-01, -7.15896923e-01, -8.31890111e-01,
#           2.61829987e+02]],
#
#        [[-1.01467375e+00, -8.45257136e-01, -9.06763784e-01,
#           2.58406677e+02],
#         [-8.27780937e-01, -7.51672854e-01, -8.60760278e-01,
#           2.60510010e+02],
#         [-8.96715235e-01, -7.66012629e-01, -8.67613881e-01,
#           2.60196655e+02],
#         ...,
#         [-8.41838535e-01, -6.97448933e-01, -7.72690016e-01,
#           2.64536682e+02],
#         [-9.03351712e-01, -7.15896923e-01, -8.31890111e-01,
#           2.61829987e+02],
#         [-8.68670599e-01, -6.81615075e-01, -7.84865373e-01,
#           2.63980011e+02]],
#
#        [[-8.27780937e-01, -7.51672854e-01, -8.60760278e-01,
#           2.60510010e+02],
#         [-8.96715235e-01, -7.66012629e-01, -8.67613881e-01,
#           2.60196655e+02],
#         [-9.72713938e-01, -7.73332609e-01, -8.51866214e-01,
#           2.60916656e+02],
#         ...,
#         [-9.03351712e-01, -7.15896923e-01, -8.31890111e-01,
#           2.61829987e+02],
#         [-8.68670599e-01, -6.81615075e-01, -7.84865373e-01,
#           2.63980011e+02],
#         [-7.89602575e-01, -5.98935204e-01, -6.84401491e-01,
#           2.68573334e+02]],
#
#        ...,
#
#        [[ 4.67424831e-02,  1.24269900e-01,  2.01330529e-01,
#           3.09070007e+02],
#         [ 1.21456748e-01,  2.98592087e-01,  1.93894224e-01,
#           3.08730011e+02],
#         [ 1.31518609e-01,  1.87680548e-01,  2.04509544e-02,
#           3.00799988e+02],
#         ...,
#         [-4.95740184e-01, -4.35442894e-01, -5.36621853e-01,
#           2.75329987e+02],
#         [-5.04517608e-01, -4.91683313e-01, -5.21748574e-01,
#           2.76010010e+02],
#         [-4.06467874e-01, -3.30356568e-01, -3.70177695e-01,
#           2.82940002e+02]],
#
#        [[ 1.21456748e-01,  2.98592087e-01,  1.93894224e-01,
#           3.08730011e+02],
#         [ 1.31518609e-01,  1.87680548e-01,  2.04509544e-02,
#           3.00799988e+02],
#         [-1.36297014e-01, -1.44158987e-01, -2.46602595e-01,
#           2.88589996e+02],
#         ...,
#         [-5.04517608e-01, -4.91683313e-01, -5.21748574e-01,
#           2.76010010e+02],
#         [-4.06467874e-01, -3.30356568e-01, -3.70177695e-01,
#           2.82940002e+02],
#         [-3.99403469e-01, -3.29012235e-01, -2.63662512e-01,
#           2.87809998e+02]],
#
#        [[ 1.31518609e-01,  1.87680548e-01,  2.04509544e-02,
#           3.00799988e+02],
#         [-1.36297014e-01, -1.44158987e-01, -2.46602595e-01,
#           2.88589996e+02],
#         [-4.95740184e-01, -4.35442894e-01, -5.36621853e-01,
#           2.75329987e+02],
#         ...,
#         [-4.06467874e-01, -3.30356568e-01, -3.70177695e-01,
#           2.82940002e+02],
#         [-3.99403469e-01, -3.29012235e-01, -2.63662512e-01,
#           2.87809998e+02],
#         [-5.13937250e-01, -5.93184524e-01, -6.92348413e-01,
#           2.68209991e+02]]])

# %%
X_normal = array_3d_normal

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

split_index = int(len(X) * 0.7)  # 95-5 split
X_train, X_test = X_normal[:split_index], X_normal[split_index:]
y_train, y_test = Y[:split_index], Y[split_index:]

print(X_train.shape)

# Reshape X_train and X_test to include the time dimension


# Step 2: Define the LSTM Model
model = Sequential([layers.Input((X_train.shape[1], X_train.shape[2])),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

# Step 3: Compile the Model


# Step 4: Train the Model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100)

# Step 5: Evaluate the Model (if needed)
# loss = model.evaluate(X_test, y_test)

# Step 6: Make Predictions
predictions = model.predict(X_test)

# Print the predicted closing prices for the next 7 days
print("Predicted closing prices for the next 7 days:")
print(predictions[-1])
# Out:
# (172, 7, 4)
# Epoch 1/100
# 6/6 [==============================] - 3s 116ms/step - loss: 1.1772 - mean_absolute_error: 0.9062 - val_loss: 0.7645 - val_mean_absolute_error: 0.6564
# Epoch 2/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.1022 - mean_absolute_error: 0.8821 - val_loss: 0.8438 - val_mean_absolute_error: 0.6994
# Epoch 3/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.0717 - mean_absolute_error: 0.8716 - val_loss: 0.8938 - val_mean_absolute_error: 0.7293
# Epoch 4/100
# 6/6 [==============================] - 0s 12ms/step - loss: 1.0523 - mean_absolute_error: 0.8641 - val_loss: 0.9465 - val_mean_absolute_error: 0.7612
# Epoch 5/100
# 6/6 [==============================] - 0s 14ms/step - loss: 1.0336 - mean_absolute_error: 0.8560 - val_loss: 0.9556 - val_mean_absolute_error: 0.7712
# Epoch 6/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.9948 - mean_absolute_error: 0.8413 - val_loss: 0.8205 - val_mean_absolute_error: 0.7060
# Epoch 7/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.9438 - mean_absolute_error: 0.8165 - val_loss: 0.8305 - val_mean_absolute_error: 0.7197
# Epoch 8/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.8895 - mean_absolute_error: 0.7919 - val_loss: 0.7381 - val_mean_absolute_error: 0.6716
# Epoch 9/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.8327 - mean_absolute_error: 0.7647 - val_loss: 0.6284 - val_mean_absolute_error: 0.6176
# Epoch 10/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.7564 - mean_absolute_error: 0.7250 - val_loss: 0.5555 - val_mean_absolute_error: 0.5905
# Epoch 11/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6798 - mean_absolute_error: 0.6856 - val_loss: 0.3877 - val_mean_absolute_error: 0.4811
# Epoch 12/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5798 - mean_absolute_error: 0.6294 - val_loss: 0.2523 - val_mean_absolute_error: 0.3872
# Epoch 13/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4774 - mean_absolute_error: 0.5629 - val_loss: 0.1903 - val_mean_absolute_error: 0.3439
# Epoch 14/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3785 - mean_absolute_error: 0.4899 - val_loss: 0.2621 - val_mean_absolute_error: 0.4656
# Epoch 15/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3093 - mean_absolute_error: 0.4399 - val_loss: 0.0675 - val_mean_absolute_error: 0.2153
# Epoch 16/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2019 - mean_absolute_error: 0.3501 - val_loss: 0.0328 - val_mean_absolute_error: 0.1488
# Epoch 17/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1431 - mean_absolute_error: 0.2792 - val_loss: 0.0441 - val_mean_absolute_error: 0.1712
# Epoch 18/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1093 - mean_absolute_error: 0.2527 - val_loss: 0.0568 - val_mean_absolute_error: 0.1923
# Epoch 19/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1000 - mean_absolute_error: 0.2486 - val_loss: 0.0585 - val_mean_absolute_error: 0.1958
# Epoch 20/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0865 - mean_absolute_error: 0.2342 - val_loss: 0.0412 - val_mean_absolute_error: 0.1690
# Epoch 21/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0765 - mean_absolute_error: 0.2199 - val_loss: 0.0328 - val_mean_absolute_error: 0.1488
# Epoch 22/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0746 - mean_absolute_error: 0.2166 - val_loss: 0.0390 - val_mean_absolute_error: 0.1565
# Epoch 23/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0732 - mean_absolute_error: 0.2157 - val_loss: 0.0241 - val_mean_absolute_error: 0.1274
# Epoch 24/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0726 - mean_absolute_error: 0.2151 - val_loss: 0.0515 - val_mean_absolute_error: 0.1850
# Epoch 25/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0944 - mean_absolute_error: 0.2536 - val_loss: 0.0248 - val_mean_absolute_error: 0.1302
# Epoch 26/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0865 - mean_absolute_error: 0.2413 - val_loss: 0.0753 - val_mean_absolute_error: 0.2397
# Epoch 27/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0728 - mean_absolute_error: 0.2078 - val_loss: 0.0322 - val_mean_absolute_error: 0.1437
# Epoch 28/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0561 - mean_absolute_error: 0.1847 - val_loss: 0.0248 - val_mean_absolute_error: 0.1299
# Epoch 29/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0527 - mean_absolute_error: 0.1844 - val_loss: 0.0172 - val_mean_absolute_error: 0.1083
# Epoch 30/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0472 - mean_absolute_error: 0.1723 - val_loss: 0.0269 - val_mean_absolute_error: 0.1317
# Epoch 31/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0443 - mean_absolute_error: 0.1643 - val_loss: 0.0169 - val_mean_absolute_error: 0.1068
# Epoch 32/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0450 - mean_absolute_error: 0.1691 - val_loss: 0.0182 - val_mean_absolute_error: 0.1097
# Epoch 33/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0425 - mean_absolute_error: 0.1621 - val_loss: 0.0122 - val_mean_absolute_error: 0.0911
# Epoch 34/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0419 - mean_absolute_error: 0.1646 - val_loss: 0.0116 - val_mean_absolute_error: 0.0893
# Epoch 35/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0415 - mean_absolute_error: 0.1586 - val_loss: 0.0153 - val_mean_absolute_error: 0.0996
# Epoch 36/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0360 - mean_absolute_error: 0.1459 - val_loss: 0.0110 - val_mean_absolute_error: 0.0860
# Epoch 37/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0328 - mean_absolute_error: 0.1417 - val_loss: 0.0145 - val_mean_absolute_error: 0.0971
# Epoch 38/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0335 - mean_absolute_error: 0.1407 - val_loss: 0.0332 - val_mean_absolute_error: 0.1610
# Epoch 39/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0375 - mean_absolute_error: 0.1501 - val_loss: 0.0180 - val_mean_absolute_error: 0.1102
# Epoch 40/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0348 - mean_absolute_error: 0.1481 - val_loss: 0.0075 - val_mean_absolute_error: 0.0719
# Epoch 41/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0298 - mean_absolute_error: 0.1334 - val_loss: 0.0130 - val_mean_absolute_error: 0.0926
# Epoch 42/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0312 - mean_absolute_error: 0.1375 - val_loss: 0.0071 - val_mean_absolute_error: 0.0685
# Epoch 43/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0269 - mean_absolute_error: 0.1264 - val_loss: 0.0071 - val_mean_absolute_error: 0.0673
# Epoch 44/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0229 - mean_absolute_error: 0.1180 - val_loss: 0.0123 - val_mean_absolute_error: 0.0925
# Epoch 45/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0252 - mean_absolute_error: 0.1258 - val_loss: 0.0077 - val_mean_absolute_error: 0.0702
# Epoch 46/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0211 - mean_absolute_error: 0.1124 - val_loss: 0.0097 - val_mean_absolute_error: 0.0810
# Epoch 47/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0189 - mean_absolute_error: 0.1037 - val_loss: 0.0048 - val_mean_absolute_error: 0.0543
# Epoch 48/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0179 - mean_absolute_error: 0.1014 - val_loss: 0.0046 - val_mean_absolute_error: 0.0535
# Epoch 49/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0175 - mean_absolute_error: 0.0991 - val_loss: 0.0052 - val_mean_absolute_error: 0.0577
# Epoch 50/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0167 - mean_absolute_error: 0.0967 - val_loss: 0.0095 - val_mean_absolute_error: 0.0827
# Epoch 51/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0205 - mean_absolute_error: 0.1106 - val_loss: 0.0032 - val_mean_absolute_error: 0.0458
# Epoch 52/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0152 - mean_absolute_error: 0.0916 - val_loss: 0.0032 - val_mean_absolute_error: 0.0462
# Epoch 53/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0171 - mean_absolute_error: 0.0967 - val_loss: 0.0069 - val_mean_absolute_error: 0.0682
# Epoch 54/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0160 - mean_absolute_error: 0.0961 - val_loss: 0.0034 - val_mean_absolute_error: 0.0463
# Epoch 55/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0127 - mean_absolute_error: 0.0845 - val_loss: 0.0030 - val_mean_absolute_error: 0.0446
# Epoch 56/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0123 - mean_absolute_error: 0.0834 - val_loss: 0.0032 - val_mean_absolute_error: 0.0461
# Epoch 57/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0114 - mean_absolute_error: 0.0785 - val_loss: 0.0030 - val_mean_absolute_error: 0.0433
# Epoch 58/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0126 - mean_absolute_error: 0.0849 - val_loss: 0.0029 - val_mean_absolute_error: 0.0431
# Epoch 59/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0120 - mean_absolute_error: 0.0828 - val_loss: 0.0031 - val_mean_absolute_error: 0.0462
# Epoch 60/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0111 - mean_absolute_error: 0.0803 - val_loss: 0.0028 - val_mean_absolute_error: 0.0432
# Epoch 61/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0111 - mean_absolute_error: 0.0802 - val_loss: 0.0044 - val_mean_absolute_error: 0.0554
# Epoch 62/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0143 - mean_absolute_error: 0.0973 - val_loss: 0.0102 - val_mean_absolute_error: 0.0891
# Epoch 63/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0139 - mean_absolute_error: 0.0910 - val_loss: 0.0096 - val_mean_absolute_error: 0.0862
# Epoch 64/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0149 - mean_absolute_error: 0.0978 - val_loss: 0.0143 - val_mean_absolute_error: 0.1091
# Epoch 65/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0154 - mean_absolute_error: 0.1017 - val_loss: 0.0102 - val_mean_absolute_error: 0.0897
# Epoch 66/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0135 - mean_absolute_error: 0.0926 - val_loss: 0.0109 - val_mean_absolute_error: 0.0931
# Epoch 67/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0127 - mean_absolute_error: 0.0881 - val_loss: 0.0028 - val_mean_absolute_error: 0.0435
# Epoch 68/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0090 - mean_absolute_error: 0.0713 - val_loss: 0.0028 - val_mean_absolute_error: 0.0420
# Epoch 69/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0084 - mean_absolute_error: 0.0692 - val_loss: 0.0036 - val_mean_absolute_error: 0.0507
# Epoch 70/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0094 - mean_absolute_error: 0.0769 - val_loss: 0.0072 - val_mean_absolute_error: 0.0731
# Epoch 71/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0130 - mean_absolute_error: 0.0897 - val_loss: 0.0035 - val_mean_absolute_error: 0.0496
# Epoch 72/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0141 - mean_absolute_error: 0.0968 - val_loss: 0.0042 - val_mean_absolute_error: 0.0523
# Epoch 73/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0101 - mean_absolute_error: 0.0783 - val_loss: 0.0035 - val_mean_absolute_error: 0.0469
# Epoch 74/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0079 - mean_absolute_error: 0.0679 - val_loss: 0.0070 - val_mean_absolute_error: 0.0728
# Epoch 75/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0092 - mean_absolute_error: 0.0754 - val_loss: 0.0075 - val_mean_absolute_error: 0.0766
# Epoch 76/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0088 - mean_absolute_error: 0.0715 - val_loss: 0.0024 - val_mean_absolute_error: 0.0384
# Epoch 77/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0075 - mean_absolute_error: 0.0682 - val_loss: 0.0033 - val_mean_absolute_error: 0.0484
# Epoch 78/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0086 - mean_absolute_error: 0.0723 - val_loss: 0.0033 - val_mean_absolute_error: 0.0489
# Epoch 79/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0076 - mean_absolute_error: 0.0675 - val_loss: 0.0056 - val_mean_absolute_error: 0.0647
# Epoch 80/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0103 - mean_absolute_error: 0.0809 - val_loss: 0.0020 - val_mean_absolute_error: 0.0367
# Epoch 81/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0066 - mean_absolute_error: 0.0631 - val_loss: 0.0014 - val_mean_absolute_error: 0.0312
# Epoch 82/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0079 - mean_absolute_error: 0.0695 - val_loss: 0.0026 - val_mean_absolute_error: 0.0407
# Epoch 83/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0078 - mean_absolute_error: 0.0730 - val_loss: 0.0049 - val_mean_absolute_error: 0.0610
# Epoch 84/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0077 - mean_absolute_error: 0.0693 - val_loss: 0.0073 - val_mean_absolute_error: 0.0788
# Epoch 85/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0067 - mean_absolute_error: 0.0661 - val_loss: 0.0024 - val_mean_absolute_error: 0.0406
# Epoch 86/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0046 - mean_absolute_error: 0.0516 - val_loss: 0.0010 - val_mean_absolute_error: 0.0259
# Epoch 87/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0046 - mean_absolute_error: 0.0495 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 88/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0050 - mean_absolute_error: 0.0555 - val_loss: 0.0057 - val_mean_absolute_error: 0.0684
# Epoch 89/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0079 - mean_absolute_error: 0.0695 - val_loss: 0.0058 - val_mean_absolute_error: 0.0702
# Epoch 90/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0073 - mean_absolute_error: 0.0682 - val_loss: 9.8274e-04 - val_mean_absolute_error: 0.0266
# Epoch 91/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0050 - mean_absolute_error: 0.0553 - val_loss: 0.0014 - val_mean_absolute_error: 0.0298
# Epoch 92/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0050 - mean_absolute_error: 0.0550 - val_loss: 0.0023 - val_mean_absolute_error: 0.0405
# Epoch 93/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0045 - mean_absolute_error: 0.0505 - val_loss: 0.0017 - val_mean_absolute_error: 0.0346
# Epoch 94/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0042 - mean_absolute_error: 0.0509 - val_loss: 0.0010 - val_mean_absolute_error: 0.0255
# Epoch 95/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0039 - mean_absolute_error: 0.0486 - val_loss: 0.0030 - val_mean_absolute_error: 0.0482
# Epoch 96/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0039 - mean_absolute_error: 0.0478 - val_loss: 9.0701e-04 - val_mean_absolute_error: 0.0248
# Epoch 97/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0037 - mean_absolute_error: 0.0462 - val_loss: 0.0019 - val_mean_absolute_error: 0.0367
# Epoch 98/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0046 - mean_absolute_error: 0.0541 - val_loss: 8.6466e-04 - val_mean_absolute_error: 0.0247
# Epoch 99/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0043 - mean_absolute_error: 0.0497 - val_loss: 0.0120 - val_mean_absolute_error: 0.1061
# Epoch 100/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0068 - mean_absolute_error: 0.0641 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# 3/3 [==============================] - 1s 7ms/step
# Predicted closing prices for the next 7 days:
# [-0.7072548]

# %%
len(y_test)
# Out:
# 13

# %%
y_test
# Out:
# array([-0.74854809, -0.67371934, -0.77190504, -0.89085225, -0.84197555,
#        -0.94881182, -1.10668727, -1.15988926, -1.31257417, -1.25331672,
#        -1.28532424, -1.12961159, -1.26845539])

# %%
import matplotlib.pyplot as plt


plt.plot(predictions, label='Training Loss')
plt.plot(y_test, label='Validation Loss')
plt.ylabel('prices')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have y_pred and y_test as numpy arrays or lists
# Plotting y_pred and y_test on the same graph
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(y_pred)), y_pred, color='blue', label='Predicted Closing Prices')
plt.plot(np.arange(len(y_test)), y_test, color='red', label='Actual Closing Prices')
plt.xlabel('Index')
plt.ylabel('Closing Prices')
plt.title('Predicted vs Actual Closing Prices')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
x = X.iloc[:,:3]
x.head()
# Out:
#         low      high    volume
# 0 -1.602624 -1.610550 -0.635103
# 1 -1.397811 -1.553244 -0.826809
# 2 -1.439499 -1.584027 -0.843999
# 3 -1.372436 -1.495048 -0.754891
# 4 -1.401436 -1.613116 -0.837472

# %%
split_index = int(len(x) * 0.8)  # 80-20 split
X_train, X_test = x[:split_index], x[split_index:]
y_train, y_test = Y[:split_index], Y[split_index:]

print(X_test.head())
# Initialize and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(y_pred)
print(mse)
# Out:
#          low      high    volume
# 87 -0.139932 -0.160359  0.256214
# 88 -1.187560 -0.533388  0.407889
# 89 -1.750253 -0.981706  0.741214
# 90 -0.680059 -0.663434  0.138957
# 91 -0.799684 -0.872364 -0.091423
# [-1.52138406e-01 -9.14679236e-01 -1.41968488e+00 -6.75576819e-01
#  -8.35383873e-01 -5.28187700e-01 -5.13300236e-03  2.63303569e-01
#  -5.71407425e-02 -9.12888206e-04 -2.37340101e-01 -4.95244214e-02
#   3.15921733e-01  4.90547412e-01  2.96412565e-01 -1.02793812e-01
#  -3.58029955e-01  3.28589433e-02  2.09692688e-01  2.35732438e-01
#   3.32196896e-01  5.62180837e-01]
# 0.05465059713536269

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have y_pred and y_test as numpy arrays or lists
# Plotting y_pred and y_test on the same graph
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(y_pred)), y_pred, color='blue', label='Predicted Closing Prices')
plt.plot(np.arange(len(y_test)), y_test, color='red', label='Actual Closing Prices')
plt.xlabel('Index')
plt.ylabel('Closing Prices')
plt.title('Predicted vs Actual Closing Prices')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
